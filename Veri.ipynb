# %%
import pandas as pd

# %%
df = pd.read_csv("ai_job_dataset.csv")

# %%
df
# Out:
#         job_id                    job_title  salary_usd salary_currency  \
# 0      AI00001        AI Research Scientist       90376             USD
# 1      AI00002         AI Software Engineer       61895             USD
# 2      AI00003                AI Specialist      152626             USD
# 3      AI00004                 NLP Engineer       80215             USD
# 4      AI00005                AI Consultant       54624             EUR
# ...        ...                          ...         ...             ...
# 14995  AI14996            Robotics Engineer       38604             USD
# 14996  AI14997  Machine Learning Researcher       57811             GBP
# 14997  AI14998                 NLP Engineer      189490             USD
# 14998  AI14999                   Head of AI       79461             EUR
# 14999  AI15000     Computer Vision Engineer       56481             USD
#
#       experience_level employment_type company_location company_size  \
# ...

# %%
df[df['job_title'] == 'AI Software Engineer']
# Out:
#         job_id             job_title  salary_usd salary_currency  \
# 1      AI00002  AI Software Engineer       61895             USD
# 9      AI00010  AI Software Engineer      102557             USD
# 47     AI00048  AI Software Engineer       69020             USD
# 59     AI00060  AI Software Engineer      110222             GBP
# 63     AI00064  AI Software Engineer       99972             USD
# ...        ...                   ...         ...             ...
# 14919  AI14920  AI Software Engineer       36466             USD
# 14922  AI14923  AI Software Engineer       59649             USD
# 14940  AI14941  AI Software Engineer       40051             USD
# 14962  AI14963  AI Software Engineer       93837             USD
# 14970  AI14971  AI Software Engineer       44789             USD
#
#       experience_level employment_type company_location company_size  \
# 1                   EN              CT           Canada            M
# ...

# %%
df[df['job_title'].isin(['NLP Engineer','AI Research Scientist','AI Software Engineer'])]
# Out:
#         job_id              job_title  salary_usd salary_currency  \
# 0      AI00001  AI Research Scientist       90376             USD
# 1      AI00002   AI Software Engineer       61895             USD
# 3      AI00004           NLP Engineer       80215             USD
# 7      AI00008           NLP Engineer       70640             EUR
# 9      AI00010   AI Software Engineer      102557             USD
# ...        ...                    ...         ...             ...
# 14970  AI14971   AI Software Engineer       44789             USD
# 14979  AI14980  AI Research Scientist       33092             USD
# 14980  AI14981  AI Research Scientist       54209             USD
# 14987  AI14988  AI Research Scientist       87647             USD
# 14997  AI14998           NLP Engineer      189490             USD
#
#       experience_level employment_type company_location company_size  \
# 0                   SE              CT            China            M
# ...

# %%
df[df['job_title'].str.contains("AI")]
# Out:
#         job_id              job_title  salary_usd salary_currency  \
# 0      AI00001  AI Research Scientist       90376             USD
# 1      AI00002   AI Software Engineer       61895             USD
# 2      AI00003          AI Specialist      152626             USD
# 4      AI00005          AI Consultant       54624             EUR
# 5      AI00006           AI Architect      123574             EUR
# ...        ...                    ...         ...             ...
# 14981  AI14982     AI Product Manager      116274             USD
# 14983  AI14984           AI Architect      288661             USD
# 14985  AI14986           AI Architect       91236             USD
# 14987  AI14988  AI Research Scientist       87647             USD
# 14998  AI14999             Head of AI       79461             EUR
#
#       experience_level employment_type company_location company_size  \
# 0                   SE              CT            China            M
# ...

# %%
df[(df["years_experience"]>5) & (df["years_experience"]<10)]
# Out:
#         job_id                    job_title  salary_usd salary_currency  \
# 0      AI00001        AI Research Scientist       90376             USD
# 3      AI00004                 NLP Engineer       80215             USD
# 5      AI00006                 AI Architect      123574             EUR
# 8      AI00009                 Data Analyst      160710             USD
# 10     AI00011  Autonomous Systems Engineer      102322             USD
# ...        ...                          ...         ...             ...
# 14976  AI14977                AI Consultant      164620             USD
# 14978  AI14979                 Data Analyst      127611             USD
# 14981  AI14982           AI Product Manager      116274             USD
# 14987  AI14988        AI Research Scientist       87647             USD
# 14992  AI14993  Autonomous Systems Engineer      200047             USD
#
#       experience_level employment_type company_location company_size  \
# ...

# %%
df.sort_values('salary_usd')
# Out:
#         job_id                    job_title  salary_usd salary_currency  \
# 9549   AI09550     Computer Vision Engineer       32519             USD
# 5974   AI05975                 Data Analyst       32542             USD
# 343    AI00344                 NLP Engineer       32587             USD
# 8828   AI08829                 Data Analyst       32666             USD
# 10485  AI10486            Robotics Engineer       32692             USD
# ...        ...                          ...         ...             ...
# 317    AI00318               Data Scientist      388754             USD
# 12803  AI12804                AI Specialist      390292             USD
# 12499  AI12500        AI Research Scientist      394917             USD
# 2309   AI02310                 AI Architect      398084             USD
# 9891   AI09892  Machine Learning Researcher      399095             USD
#
#       experience_level employment_type company_location company_size  \
# ...

# %%
df.sort_values(['salary_usd' , 'years_experience'] , ascending = [False , True])
# Out:
#         job_id                    job_title  salary_usd salary_currency  \
# 9891   AI09892  Machine Learning Researcher      399095             USD
# 2309   AI02310                 AI Architect      398084             USD
# 12499  AI12500        AI Research Scientist      394917             USD
# 12803  AI12804                AI Specialist      390292             USD
# 317    AI00318               Data Scientist      388754             USD
# ...        ...                          ...         ...             ...
# 10485  AI10486            Robotics Engineer       32692             USD
# 8828   AI08829                 Data Analyst       32666             USD
# 343    AI00344                 NLP Engineer       32587             USD
# 5974   AI05975                 Data Analyst       32542             USD
# 9549   AI09550     Computer Vision Engineer       32519             USD
#
#       experience_level employment_type company_location company_size  \
# ...

# %%
df.reset_index(drop=True)
# Out:
#         job_id                    job_title  salary_usd salary_currency  \
# 0      AI00001        AI Research Scientist       90376             USD
# 1      AI00002         AI Software Engineer       61895             USD
# 2      AI00003                AI Specialist      152626             USD
# 3      AI00004                 NLP Engineer       80215             USD
# 4      AI00005                AI Consultant       54624             EUR
# ...        ...                          ...         ...             ...
# 14995  AI14996            Robotics Engineer       38604             USD
# 14996  AI14997  Machine Learning Researcher       57811             GBP
# 14997  AI14998                 NLP Engineer      189490             USD
# 14998  AI14999                   Head of AI       79461             EUR
# 14999  AI15000     Computer Vision Engineer       56481             USD
#
#       experience_level employment_type company_location company_size  \
# ...

# %%
df.loc[df["job_title"] == "AI Software Engineer", "salary_usd"].mean()
# Out:
# np.float64(114273.20153061225)

# %%
df["company_location"].value_counts()
# Out:
# company_location
# Germany           814
# Denmark           778
# Canada            769
# France            769
# Austria           765
# Singapore         764
# China             763
# India             754
# Sweden            752
# Israel            751
# Ireland           750
# Switzerland       746
# Japan             733
# Finland           733
# Australia         732
# Netherlands       731
# United Kingdom    729
# United States     724
# South Korea       722
# Norway            721
# Name: count, dtype: int64

# %%
df.groupby("job_title")["salary_usd"].mean()
# Out:
# job_title
# AI Architect                   117436.513619
# AI Consultant                  113671.870739
# AI Product Manager             114680.909825
# AI Research Scientist          117897.925926
# AI Software Engineer           114273.201531
# AI Specialist                  120570.758242
# Autonomous Systems Engineer    111396.557272
# Computer Vision Engineer       113472.707182
# Data Analyst                   111321.180501
# Data Engineer                  115970.720961
# Data Scientist                 115819.008333
# Deep Learning Engineer         113725.632312
# Head of AI                     118542.968627
# ML Ops Engineer                115431.335172
# Machine Learning Engineer      118827.919689
# Machine Learning Researcher    112621.747525
# NLP Engineer                   112670.937008
# Principal Data Scientist       116305.219346
# Research Scientist             116066.502695
# Robotics Engineer              116470.793149
# Name: salary_usd, dtype: float64

# %% [raw]
# salary_df = df.groupby("job_title")["salary_usd"].mean().reset_index()

# %%
salary_df = df.groupby("job_title")["salary_usd"].mean().reset_index()

# %%
salary_df = df.groupby("job_title")["salary_usd"].mean().reset_index()
salary_df.plot(x="job_title", y="salary_usd")
# Out:
# <Axes: xlabel='job_title'>
